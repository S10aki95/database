# %%
import numpy as np
import pandas as pd
import pandas_datareader as pdr
from sqlalchemy import create_engine
import pymysql

# %%
data = pdr.stooq.StooqDailyReader(symbols='9984.jp', start='JAN-01-1950', end="AUG-26-2020").read().sort_values(by='Date',ascending=True)

# %%
data[['High', 'Low']].plot()

# %%
def save(data):
    engine = create_engine("mysql+pymysql://admin:4wGET1ts3ITZXbUmkYbl@redash.cqhpwuvmin0l.us-east-2.rds.amazonaws.com/stock_test")
    con = engine.connect()
    data.to_sql(name='softbank',con=con,if_exists='replace')
    con.close()

# %%
save(data)
